# %%
import pandas as pd
data = pd.read_csv("logs_concurrent.csv")
data.head(20)
# Out:
#                      timestamp mode selected_model  \
# 0   2025-11-30T16:34:24.550690  cpu           phi3
# 1   2025-11-30T16:34:24.552243  cpu           phi3
# 2   2025-11-30T16:34:24.547461  cpu           phi3
# 3   2025-11-30T16:34:24.548620  cpu           phi3
# 4   2025-11-30T16:34:24.552895  cpu           phi3
# 5   2025-11-30T16:34:46.340934  gpu      gemma2:2b
# 6   2025-11-30T16:34:46.354911  gpu      gemma2:2b
# 7   2025-11-30T16:34:46.345748  gpu      gemma2:2b
# 8   2025-11-30T16:34:46.342426  gpu      gemma2:2b
# 9   2025-11-30T16:34:46.343657  gpu      gemma2:2b
# 10  2025-11-30T16:34:46.346801  gpu      gemma2:2b
# 11  2025-11-30T16:34:46.343200  gpu      gemma2:2b
# 12  2025-11-30T16:34:46.349395  gpu      gemma2:2b
# 13  2025-11-30T16:34:46.353045  gpu      gemma2:2b
# 14  2025-11-30T16:34:46.350923  gpu      gemma2:2b
# 15  2025-11-30T16:36:15.768091  gpu      gemma2:2b
# 16  2025-11-30T16:36:15.765407  gpu      gemma2:2b
# ...

# %%
import pandas as pd
data = pd.read_csv("logs_sequential.csv")
data.head(20)
# Out:
#                     timestamp mode selected_model  \
# 0  2025-11-30T16:43:02.069013  cpu           phi3
# 1  2025-11-30T16:43:06.974706  cpu           phi3
# 2  2025-11-30T16:43:10.002200  cpu           phi3
# 3  2025-11-30T16:43:13.749177  cpu           phi3
# 4  2025-11-30T16:43:17.540164  cpu           phi3
# 5  2025-11-30T16:43:20.896625  cpu           phi3
# 6  2025-11-30T16:43:30.371035  cpu           phi3
# 7  2025-11-30T16:43:37.948364  gpu      gemma2:2b
# 8  2025-11-30T16:43:52.006667  gpu      gemma2:2b
# 9  2025-11-30T16:44:00.301826  gpu      gemma2:2b
#
#                                      decision_reason  latency_s  \
# 0  Tiny prompt (len=3), CPU optimal | Queue depth: 1      3.887
# 1  Tiny prompt (len=2), CPU optimal | Queue depth: 1      2.002
# 2  Tiny prompt (len=2), CPU optimal | Queue depth: 1      2.719
# 3  GPU busy (80.0%), routing small prompt to CPU ...      2.778
# 4  Tiny prompt (len=4), CPU optimal | Queue depth: 1      2.340
# ...
